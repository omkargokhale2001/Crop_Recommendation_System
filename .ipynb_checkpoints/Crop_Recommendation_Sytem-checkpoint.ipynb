# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading in dataset

# %%
df = pd.read_csv("Crop_recommendation.csv")
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_seperate = df.groupby('label').mean()
df_count = df['label'].value_counts()
df_count
# Out:
# coconut        100
# blackgram      100
# banana         100
# muskmelon      100
# rice           100
# grapes         100
# papaya         100
# mango          100
# cotton         100
# pomegranate    100
# kidneybeans    100
# apple          100
# coffee         100
# maize          100
# orange         100
# chickpea       100
# watermelon     100
# pigeonpeas     100
# jute           100
# mungbean       100
# lentil         100
# mothbeans      100
# Name: label, dtype: int64

# %%
plt.figure()
sns.pairplot(df,hue='label' ,height=3)
plt.show()

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### KNN Classifier

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
le = LabelEncoder()
scaler = MinMaxScaler()
y = df['label']
X = df.drop(['label'],axis=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier()
grid_params = {'n_neighbors':[1,3,5,7,9]}
grid = GridSearchCV(estimator = model_knn,param_grid=grid_params)
grid.fit(X,y)
model1 = KNeighborsClassifier(n_neighbors=grid.best_estimator_.n_neighbors).fit(X_train_scaled,y_train)
score_scaled = model1.score(X_test_scaled,y_test)
model2 = KNeighborsClassifier(n_neighbors=grid.best_estimator_.n_neighbors).fit(X_train,y_train)
score = model2.score(X_test,y_test)
score,score_scaled
# Out:
# (0.9781818181818182, 0.9854545454545455)

# %%
# Predicting a sample value:
example = X.iloc[500]
lst=[]
df['predict_label'] = model1.predict(scaler.transform(X))
ans = df['predict_label'].value_counts()
for i in example:
    lst.append(i)
data1 = np.array(lst).reshape(1,-1)
data1 = scaler.transform(data1)
(model1.predict(data1),y.iloc[500])
# Out:
# (array(['mothbeans'], dtype=object), 'mothbeans')

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model_logic = LogisticRegression(C=1000,max_iter=1000,multi_class='multinomial',solver='lbfgs').fit(X_train_scaled,y_train)
# grid_params={'C':[0.01,0.1,1,10,100,1000]}
# grid = GridSearchCV(estimator=model_logic,param_grid=grid_params)
# grid.fit(X,y)
# grid.best_estimator_.C
score = model_logic.score(X_test_scaled,y_test)
score
# Out:
# 0.98

# %% [markdown]
# #### Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

# %%
model_svc = SVC()
grid_params = {'kernel':['linear','rbf','poly'],'degree':[1,2,3,4,5]}
grid_svc = GridSearchCV(estimator=model_svc,param_grid=grid_params)
grid_svc.fit(X_train_scaled,y_train)
kernel_best,degree_best = grid_svc.best_estimator_.kernel,grid_svc.best_estimator_.degree
model_svc=SVC(kernel=kernel_best,degree = degree_best).fit(X_train_scaled,y_train)
score = model_svc.score(X_test_scaled,y_test)
score
# Out:
# 0.9854545454545455

# %%
# Predicting a sample value
example = X.iloc[500]
lst=[]
df['predict_label'] = model_svc.predict(scaler.transform(X))
ans = df['predict_label'].value_counts()
for i in example:
    lst.append(i)
data1 = np.array(lst).reshape(1,-1)
data1 = scaler.transform(data1)
(model_svc.predict(data1),y.iloc[500])
# Out:
# (array(['mothbeans'], dtype=object), 'mothbeans')

# %% [markdown]
# #### Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.inspection import permutation_importance

# %%
model_tree = DecisionTreeClassifier()
grid_params = {'max_depth':[1,2,3,4,5,6,7,8,9],'max_leaf_nodes':[2,3,4,5,6,7,8,9]}
grid_tree = GridSearchCV(estimator=model_tree,param_grid=grid_params)
grid_tree.fit(X_train_scaled,y_train)
model_tree = DecisionTreeClassifier().fit(X_train_scaled,y_train)
model_tree.score(X_test_scaled,y_test)
# Out:
# 0.9890909090909091

# %%
#Important features
importances = permutation_importance(model_tree,X_test_scaled,y_test)
df_feature_importance = pd.DataFrame(importances.importances_mean,index=X.columns)
df_feature_importance
# Out:
#                     0
# N            0.170909
# P            0.344364
# K            0.330909
# temperature  0.008000
# humidity     0.552364
# ph           0.054182
# rainfall     0.381818

# %%
# Example
example = X.iloc[500]
lst=[]
df['predict_label'] = model_tree.predict(scaler.transform(X))
ans = df['predict_label'].value_counts()
for i in example:
    lst.append(i)
data1 = np.array(lst).reshape(1,-1)
data1 = scaler.transform(data1)
(model_tree.predict(data1),y.iloc[500])
# Out:
# (array(['mothbeans'], dtype=object), 'mothbeans')

# %% [markdown]
# #### Accuracy using roc_auc_score

# %%
from sklearn.metrics import roc_auc_score

# %%
knn_roc_score = roc_auc_score(y_test,model1.predict_proba(X_test_scaled),multi_class='ovr')
knn_roc_score
# Out:
# 0.9956848994181275

# %%
logic_roc_score = roc_auc_score(y_test,model_logic.predict_proba(X_test_scaled),multi_class='ovr')
logic_roc_score
# Out:
# 0.9998115902840209

# %%
model_svc_new=SVC(kernel=kernel_best,degree = degree_best,probability = True).fit(X_train_scaled,y_train)
y_predict_svm = le.transform(model_svc.predict(X_test_scaled))
svm_roc_score = roc_auc_score(y_test,model_svc_new.predict_proba(X_test_scaled),multi_class='ovr')
svm_roc_score
# Out:
# 0.999685756525598

# %%
tree_roc_score = roc_auc_score(y_test,model_tree.predict_proba(X_test_scaled),multi_class='ovr')
tree_roc_score
# Out:
# 0.994453124450326

# %%
df_scores = pd.DataFrame([knn_roc_score,logic_roc_score,svm_roc_score,tree_roc_score],index = ['KNN','Logistic Regression','SVM','Decision Trees'])
df_scores
# Out:
#                             0
# KNN                  0.995685
# Logistic Regression  0.999812
# SVM                  0.999686
# Decision Trees       0.994453

# %% [markdown]
# ### The overall score of the Logistic Regression Model is the best hence we use model_logic to solve this problem
